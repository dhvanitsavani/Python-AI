# %% [markdown]
# # Pandas

# %% [markdown]
# ## Countries Project

# %% [markdown]
# ### Task

# %% [markdown]
# #### Read anime.csv file using pandas & perform below operations on it.
# - Which country has the highest population
# - What is the capital of the country with highest population
# - Which country has the least population
# - What is the capital of the country with least population
# - Give me top 5 countries with highest democratic score
# - How many total regions are there
# - How many countries lie in Eastern Europe region
# - Who is the political leader of the 2nd highest populated country
# - How many countries are there whose political leaderss are unknown
# - How many countries have Republic in their full name
# - Which country in African region has highest population

# %% [markdown]
# ### Implementation

# %% [markdown]
# #### Read csv file & create a datagrame

# %%
import pandas as pd

countries_df = pd.read_csv('Countries.csv')
countries_df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %% [markdown]
# #### Preprocessing

# %%
countries_df.shape
# Out:
# (194, 64)

# %%
countries_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    str
#  1   country_long                             194 non-null    str
#  2   currency                                 194 non-null    str
#  3   capital_city                             194 non-null    str
#  4   region                                   194 non-null    str
#  5   continent                                194 non-null    str
#  6   demonym                                  194 non-null    str
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
countries_df.columns
# Out:
# Index(['country', 'country_long', 'currency', 'capital_city', 'region',
#        'continent', 'demonym', 'latitude', 'longitude', 'agricultural_land',
#        'forest_area', 'land_area', 'rural_land', 'urban_land',
#        'central_government_debt_pct_gdp', 'expense_pct_gdp', 'gdp',
#        'inflation', 'self_employed_pct', 'tax_revenue_pct_gdp',
#        'unemployment_pct', 'vulnerable_employment_pct',
#        'electricity_access_pct', 'alternative_nuclear_energy_pct',
#        'electricty_production_coal_pct',
#        'electricty_production_hydroelectric_pct',
#        'electricty_production_gas_pct', 'electricty_production_nuclear_pct',
#        'electricty_production_oil_pct', 'electricty_production_renewable_pct',
#        'energy_imports_pct', 'fossil_energy_consumption_pct',
#        'renewable_energy_consumption_pct', 'co2_emissions',
#        'methane_emissions', 'nitrous_oxide_emissions',
#        'greenhouse_other_emissions', 'urban_population_under_5m',
# ...

# %% [markdown]
# #### Highest population country

# %%
countries_df[countries_df['population'] == countries_df['population'].max()]
# Out:
#    country       country_long      currency capital_city         region  \
# 75   India  Republic of India  Indian rupee    New Delhi  Southern Asia
#
#    continent demonym  latitude  longitude  agricultural_land  ...  population  \
# 75      Asia  Indian      20.0       77.0          1790450.0  ...  1417173173
#
#     women_parliament_seats_pct  rural_population  urban_population  press  \
# 75                     14.9446         908804812         508368361   1.71
#
#     democracy_score    democracy_type  median_age  political_leader  \
# 75             7.23  Flawed democracy        23.9     Narendra Modi
#
#              title
# 75  Prime Minister
#
# [1 rows x 64 columns]

# %% [markdown]
# #### Capital of highest populated country

# %%
countries_df[countries_df['population'] == countries_df['population'].max()]['capital_city']
# Out:
# 75    New Delhi
# Name: capital_city, dtype: str

# %% [markdown]
# #### Least population country

# %%
countries_df[countries_df['population'] == countries_df['population'].min()]
# Out:
#     country country_long           currency capital_city     region continent  \
# 179  Tuvalu       Tuvalu  Australian dollar     Funafuti  Polynesia   Oceania
#
#       demonym  latitude  longitude  agricultural_land  ...  population  \
# 179  Tuvaluan      -8.0      178.0               18.0  ...       11312
#
#      women_parliament_seats_pct  rural_population  urban_population  press  \
# 179                        6.25              3900              7412    0.0
#
#      democracy_score  democracy_type  median_age  political_leader  \
# 179              0.0         Unknown        21.0     Kausea Natano
#
#               title
# 179  Prime Minister
#
# [1 rows x 64 columns]

# %% [markdown]
# #### Capital of least populated country

# %%
countries_df[countries_df['population'] == countries_df['population'].min()]['capital_city']
# Out:
# 179    Funafuti
# Name: capital_city, dtype: str

# %% [markdown]
# #### Top 5 highest democratic score countries

# %%
dummy_countries_df = countries_df.copy()
top_5_democracy_score_countries_df = pd.DataFrame(columns=countries_df.columns)

for i in range(5):
    top_5_democracy_score_countries_df = pd.concat([top_5_democracy_score_countries_df, dummy_countries_df.loc[[dummy_countries_df['democracy_score'].idxmax()]]])
    dummy_countries_df.drop(dummy_countries_df['democracy_score'].idxmax(), inplace=True)

del dummy_countries_df

top_5_democracy_score_countries_df
# Out:
#          country         country_long            currency capital_city  \
# 127       Norway    Kingdom of Norway     Norwegian krone         Oslo
# 74       Iceland  Republic of Iceland       Iceland krona    Reykjavík
# 164       Sweden    Kingdom of Sweden       Swedish krona    Stockholm
# 122  New Zealand          New Zealand  New Zealand dollar   Wellington
# 46       Denmark   Kingdom of Denmark        Danish krone   Copenhagen
#
#                         region continent        demonym latitude longitude  \
# 127            Northern Europe    Europe      Norwegian     62.0      10.0
# 74             Northern Europe    Europe      Icelander     65.0     -18.0
# 164            Northern Europe    Europe        Swedish     62.0      15.0
# 122  Australia and New Zealand   Oceania  New Zealander    -41.0     174.0
# 46             Northern Europe    Europe         Danish     56.0      10.0
#
#     agricultural_land  ... population women_parliament_seats_pct  \
# ...

# %% [markdown]
# #### Total regions

# %%
countries_df['region'].nunique()
# Out:
# 22

# %% [markdown]
# #### Total countries in Eastern Europe region

# %%
int(countries_df[countries_df['region'] == 'Eastern Europe']['country'].count())
# Out:
# 10

# %% [markdown]
# #### Political leader of second highest populated country

# %%
dummy_countries_df = countries_df.copy()
dummy_countries_df.drop(dummy_countries_df['population'].idxmax(), inplace=True)

print(dummy_countries_df[dummy_countries_df['population'] == dummy_countries_df['population'].max()]['political_leader'].iloc[0])
del dummy_countries_df
# Out:
# Xi Jinping

# %% [markdown]
# #### Total number of countries having unknown political leaders

# %%
int(countries_df[countries_df['political_leader'].isna()]['country'].count())
# Out:
# 7

# %% [markdown]
# #### Total number of countries having Republic in name

# %%
int(countries_df[countries_df['country_long'].str.contains(r'Republic', regex=True)]['country'].count())
# Out:
# 125

# %% [markdown]
# #### Highest populated country in African region

# %%
african_countries = countries_df[countries_df['continent'] == 'Africa']
print(african_countries[african_countries['population'] == african_countries['population'].max()][['country', 'population']])
del african_countries
# Out:
#      country  population
# 125  Nigeria   218541212
