# %% [markdown]
# # Pandas

# %% [markdown]
# ## Anime Project

# %% [markdown]
# ### Task

# %% [markdown]
# #### Read anime.csv file using pandas & perform below operations on it.
# * make a new column for episode count
# * make a new column for time stamp
# * which anime has the highest score
# * give me top 5 highest scoring anime
# * which anime has the highest episode count
# * animes with top 5 episode count
# * which is the longest running anime

# %% [markdown]
# ### Implementation

# %% [markdown]
# #### Read csv file & create a dataframe

# %%
import numpy as np
import pandas as pd

anime_df = pd.read_csv('anime.csv')
anime_df
# Out:
#     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %% [markdown]
# #### Make column for episodes count

# %%
def extract_episodes_count(title):
    is_eps_num = False
    ans = ""

    for i in title:
        if i == ' ' and is_eps_num:
            return int(ans)
        if is_eps_num:
            ans += i
        if i == '(':
            is_eps_num = True

# %%
anime_df['Episodes'] = anime_df['Title'].apply(extract_episodes_count)
anime_df.head()               # Only shows first five rows
# Out:
#    Rank                                              Title  Score  Episodes
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10

# %% [markdown]
# #### Make column for time stamp

# %%
import re

time_stamp_pattern = r'[A-Za-z]{3} \d{4} - [A-Za-z]{3} \d{4}'

def extract_time_stamp(title):
    match = re.search(time_stamp_pattern, title)

    if match:
        return match.group()

# %%
anime_df['Time Stamp'] = anime_df['Title'].apply(extract_time_stamp)
anime_df.head()
# Out:
#    Rank                                              Title  Score  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#             Time Stamp
# 0  Apr 2009 - Jul 2010
# 1  Apr 2011 - Sep 2011
# 2  Oct 2022 - Dec 2022
# 3  Apr 2015 - Mar 2016
# 4  Apr 2019 - Jul 2019

# %% [markdown]
# #### Make column for total months of time stamp

# %%
months_codes = {
    'jan': 1, 'feb': 2, 'mar': 3,
    'apr': 4, 'may': 5, 'jun': 6,
    'jul': 7, 'aug': 8, 'sep': 9,
    'oct': 10, 'nov': 11, 'dec': 12,
}

month_pattern = r'[a-zA-Z]{3}'
year_pattern = r'\d{4}'

# %%
def extract_total_months(title):
    months = re.findall(month_pattern, title)
    month_1 = months[0].lower()
    month_2 = months[1].lower()
    month_sub = months_codes[month_2] - months_codes[month_1] + 1

    years = re.findall(year_pattern, title)
    year_1 = int(years[0])
    year_2 = int(years[1])
    year_sub = (year_2 - year_1) * 12

    return month_sub + year_sub

# %%
anime_df['Total Months'] = anime_df['Time Stamp'].apply(extract_total_months)
anime_df.head()
# Out:
#    Rank                                              Title  Score  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#             Time Stamp  Total Months
# 0  Apr 2009 - Jul 2010            16
# 1  Apr 2011 - Sep 2011             6
# 2  Oct 2022 - Dec 2022             3
# 3  Apr 2015 - Mar 2016            12
# 4  Apr 2019 - Jul 2019             4

# %% [markdown]
# #### Highest score

# %%
anime_df[anime_df['Rank'] == 1]
# Out:
#    Rank                                              Title  Score  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...    9.1        64
#
#             Time Stamp  Total Months
# 0  Apr 2009 - Jul 2010            16

# %% [markdown]
# #### Top 5 highest score anime

# %%
anime_df[anime_df['Rank'] <= 5]
# Out:
#    Rank                                              Title  Score  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#             Time Stamp  Total Months
# 0  Apr 2009 - Jul 2010            16
# 1  Apr 2011 - Sep 2011             6
# 2  Oct 2022 - Dec 2022             3
# 3  Apr 2015 - Mar 2016            12
# 4  Apr 2019 - Jul 2019             4

# %% [markdown]
# #### Highest episode count

# %%
anime_df[anime_df['Episodes'] == anime_df['Episodes'].max()]
# Out:
#     Rank                                              Title  Score  Episodes  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94       201
#
#              Time Stamp  Total Months
# 15  Apr 2006 - Mar 2010            48

# %% [markdown]
# #### Top 5 highest episodes count anime

# %%
highest_episodes_top_5_df = pd.DataFrame(columns=anime_df.columns)
dummy_anime_df = anime_df.copy()

for i in range(5):
    highest_episodes_top_5_df = pd.concat([highest_episodes_top_5_df, dummy_anime_df.loc[[dummy_anime_df['Episodes'].idxmax()]]])
    dummy_anime_df.drop(dummy_anime_df['Episodes'].idxmax(), inplace=True)

del dummy_anime_df
highest_episodes_top_5_df
# Out:
#    Rank                                              Title Score Episodes  \
# 15   16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...  8.94      201
# 7     8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...  9.04      148
# 11   12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...  9.02      110
# 42   43  Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...  8.76       75
# 24   25  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...  8.87       74
#
#              Time Stamp Total Months
# 15  Apr 2006 - Mar 2010           48
# 7   Oct 2011 - Sep 2014           36
# 11  Jan 1988 - Mar 1997          111
# 42  Oct 2000 - Mar 2002           18
# 24  Apr 2004 - Sep 2005           18

# %% [markdown]
# #### Longest running time

# %%
anime_df[anime_df['Total Months'] == anime_df['Total Months'].max()]
# Out:
#     Rank                                              Title  Score  Episodes  \
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02       110
#
#              Time Stamp  Total Months
# 11  Jan 1988 - Mar 1997           111
