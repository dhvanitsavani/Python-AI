# %% [markdown]
# # Pandas

# %% [markdown]
# ## Basics

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series

# %% [markdown]
# #### Creation of series

# %% [markdown]
# ##### Using list

# %%
l = [10,20,30]

s = pd.Series(l)
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# ##### Using dictionary

# %%
dictionary = {1:10, 2:20, 3:30}

s = pd.Series(dictionary)
s
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# ##### Using numpy array

# %%
arr = np.arange(5)
s = pd.Series(arr)
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %% [markdown]
# ##### index

# %%
import string
columns = list(string.ascii_lowercase[:6])

s = pd.Series(np.arange(10,70,10), index=columns)
s
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %% [markdown]
# ##### datatype

# %%
s2 = pd.Series(np.arange(5), dtype='f4')
s2
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# 3    3.0
# 4    4.0
# dtype: float32

# %% [markdown]
# #### Selection and Slicing

# %% [markdown]
# ##### Selection using iloc

# %%
s.iloc[1:4]
# Out:
# b    20
# c    30
# d    40
# dtype: int64

# %%
s.iloc[[1, 3, 0]]
# Out:
# b    20
# d    40
# a    10
# dtype: int64

# %% [markdown]
# ##### Selection using get

# %%
# s['g'] will produce an error
print(s.get('g'))

# You can also give it's default value
print(s.get('g', default='Key not found'))
# Out:
# None
# Key not found

# %% [markdown]
# ##### Boolean selection

# %%
s[s > 30]
# Out:
# d    40
# e    50
# f    60
# dtype: int64

# %% [markdown]
# ##### Slicing

# %%
slice1 = s[1:4]

slice1
# Out:
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# #### Operations

# %% [markdown]
# ##### Vectorized Operations

# %%
# Every value will be added by 10
s + 10
# Out:
# a    20
# b    30
# c    40
# d    50
# e    60
# f    70
# dtype: int64

# %% [markdown]
# ##### Useful functions

# %%
# Aggregation functions such as sum, min, max, mean, std, median
s.sum()
# Out:
# np.int64(210)

# %% [markdown]
# ##### Creating numpy array from series

# %%
print(s.array, '\n')
print(s.to_numpy())
# Out:
# <NumpyExtensionArray>
# [10, 20, 30, 40, 50, 60]
# Length: 6, dtype: int64
#
# [10 20 30 40 50 60]

# %% [markdown]
# ### Dataframes

# %% [markdown]
# #### Creation of Dataframes

# %% [markdown]
# ##### Using Dictionary

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ##### Using List

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
print(df2)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list, columns =columns)
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ##### Use of date_range() and index

# %%
dates = pd.date_range("2025-01-20", periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2025-01-20 -0.545678 -0.427257 -1.292691  0.748727
# 2025-01-21  0.687145  0.184030  0.585852 -0.533815
# 2025-01-22  0.818708 -0.090662  0.538791  0.070809
# 2025-01-23  1.804694  0.135559 -0.007469 -0.951179
# 2025-01-24 -0.126337 -0.293950 -0.712291  0.517237
# 2025-01-25 -0.697757  0.775963  0.011384  1.002143

# %% [markdown]
# #### Viewing Data

# %% [markdown]
# ##### Header and Footer of Dataframe

# %%
print(df.head(), '\n')
print(df.tail(3))
# Out:
#                    A         B         C         D
# 2025-01-20 -0.545678 -0.427257 -1.292691  0.748727
# 2025-01-21  0.687145  0.184030  0.585852 -0.533815
# 2025-01-22  0.818708 -0.090662  0.538791  0.070809
# 2025-01-23  1.804694  0.135559 -0.007469 -0.951179
# 2025-01-24 -0.126337 -0.293950 -0.712291  0.517237
#
#                    A         B         C         D
# 2025-01-23  1.804694  0.135559 -0.007469 -0.951179
# 2025-01-24 -0.126337 -0.293950 -0.712291  0.517237
# 2025-01-25 -0.697757  0.775963  0.011384  1.002143

# %% [markdown]
# ##### Information about Dataframe

# %%
print(df.index, '\n')
print(df.columns, '\n')
print(df.dtypes)
# Out:
# DatetimeIndex(['2025-01-20', '2025-01-21', '2025-01-22', '2025-01-23',
#                '2025-01-24', '2025-01-25'],
#               dtype='datetime64[us]', freq='D')
#
# Index(['A', 'B', 'C', 'D'], dtype='str')
#
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
print(df.info(), '\n')
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 6 entries, 2025-01-20 to 2025-01-25
# Freq: D
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       6 non-null      float64
#  1   B       6 non-null      float64
#  2   C       6 non-null      float64
#  3   D       6 non-null      float64
# dtypes: float64(4)
# memory usage: 240.0 bytes
# None
#
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.323463  0.047280 -0.146071  0.142320
# std    0.956263  0.428515  0.732679  0.762312
# min   -0.697757 -0.427257 -1.292691 -0.951179
# 25%   -0.440843 -0.243128 -0.536085 -0.382659
# 50%    0.280404  0.022448  0.001957  0.294023
# 75%    0.785817  0.171912  0.406939  0.690855
# max    1.804694  0.775963  0.585852  1.002143

# %% [markdown]
# ##### Transformation of Dataframe

# %%
print(df.T, '\n')
print(df.to_numpy())
# Out:
#    2025-01-20  2025-01-21  2025-01-22  2025-01-23  2025-01-24  2025-01-25
# A   -0.545678    0.687145    0.818708    1.804694   -0.126337   -0.697757
# B   -0.427257    0.184030   -0.090662    0.135559   -0.293950    0.775963
# C   -1.292691    0.585852    0.538791   -0.007469   -0.712291    0.011384
# D    0.748727   -0.533815    0.070809   -0.951179    0.517237    1.002143
#
# [[-0.54567758 -0.4272572  -1.29269128  0.74872748]
#  [ 0.68714464  0.1840297   0.58585248 -0.53381485]
#  [ 0.81870834 -0.09066194  0.5387908   0.07080851]
#  [ 1.80469433  0.13555881 -0.00746935 -0.95117907]
#  [-0.12633736 -0.29395018 -0.71229061  0.51723689]
#  [-0.69775691  0.77596317  0.01138414  1.00214268]]

# %% [markdown]
# ##### Sorting in Dataframe

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2025-01-20  0.748727 -1.292691 -0.427257 -0.545678
# 2025-01-21 -0.533815  0.585852  0.184030  0.687145
# 2025-01-22  0.070809  0.538791 -0.090662  0.818708
# 2025-01-23 -0.951179 -0.007469  0.135559  1.804694
# 2025-01-24  0.517237 -0.712291 -0.293950 -0.126337
# 2025-01-25  1.002143  0.011384  0.775963 -0.697757

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2025-01-20 -0.545678 -0.427257 -1.292691  0.748727
# 2025-01-24 -0.126337 -0.293950 -0.712291  0.517237
# 2025-01-22  0.818708 -0.090662  0.538791  0.070809
# 2025-01-23  1.804694  0.135559 -0.007469 -0.951179
# 2025-01-21  0.687145  0.184030  0.585852 -0.533815
# 2025-01-25 -0.697757  0.775963  0.011384  1.002143

# %% [markdown]
# ### Selection

# %% [markdown]
# ##### Getitem ([])

# %%
# Column
df['A']
# Out:
# 2025-01-20   -0.545678
# 2025-01-21    0.687145
# 2025-01-22    0.818708
# 2025-01-23    1.804694
# 2025-01-24   -0.126337
# 2025-01-25   -0.697757
# Freq: D, Name: A, dtype: float64

# %%
# Multiple columns
df[['A', 'B']]
# Out:
#                    A         B
# 2025-01-20 -0.545678 -0.427257
# 2025-01-21  0.687145  0.184030
# 2025-01-22  0.818708 -0.090662
# 2025-01-23  1.804694  0.135559
# 2025-01-24 -0.126337 -0.293950
# 2025-01-25 -0.697757  0.775963

# %%
# rows
df[0:3]
# Out:
#                    A         B         C         D
# 2025-01-20 -0.545678 -0.427257 -1.292691  0.748727
# 2025-01-21  0.687145  0.184030  0.585852 -0.533815
# 2025-01-22  0.818708 -0.090662  0.538791  0.070809

# %% [markdown]
# ##### Selection by label

# %%
# row
df.loc[dates[0]]
# Out:
# A   -0.545678
# B   -0.427257
# C   -1.292691
# D    0.748727
# Name: 2025-01-20 00:00:00, dtype: float64

# %%
# all rows with only 'A' and 'B' column
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2025-01-20 -0.545678 -0.427257
# 2025-01-21  0.687145  0.184030
# 2025-01-22  0.818708 -0.090662
# 2025-01-23  1.804694  0.135559
# 2025-01-24 -0.126337 -0.293950
# 2025-01-25 -0.697757  0.775963

# %%
# subset of selected rows and columns
df.loc['2025-01-22':'2025-01-25', ['A', 'B']]
# Out:
#                    A         B
# 2025-01-22  0.818708 -0.090662
# 2025-01-23  1.804694  0.135559
# 2025-01-24 -0.126337 -0.293950
# 2025-01-25 -0.697757  0.775963

# %%
# Single element
print(df.loc[dates[0], 'A'])
print(df.at[dates[0], 'A'])
# Out:
# -0.5456775758094473
# -0.5456775758094473

# %% [markdown]
# ##### Selection by position

# %%
# row
df.iloc[2]
# Out:
# A    0.818708
# B   -0.090662
# C    0.538791
# D    0.070809
# Name: 2025-01-22 00:00:00, dtype: float64

# %%
# subset
df.iloc[1:3, :2]
# Out:
#                    A         B
# 2025-01-21  0.687145  0.184030
# 2025-01-22  0.818708 -0.090662

# %%
# list of integer position locations
df.iloc[[1, 2, 4], [1, 3]]
# Out:
#                    B         D
# 2025-01-21  0.184030 -0.533815
# 2025-01-22 -0.090662  0.070809
# 2025-01-24 -0.293950  0.517237

# %%
# Single element
print(df.iloc[1, 2])
print(df.iat[1, 2])
# Out:
# 0.5858524821428962
# 0.5858524821428962

# %% [markdown]
# ##### Boolean indexing

# %%
#Select rows where df.A is greater than 0.
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2025-01-21  0.687145  0.184030  0.585852 -0.533815
# 2025-01-22  0.818708 -0.090662  0.538791  0.070809
# 2025-01-23  1.804694  0.135559 -0.007469 -0.951179

# %%
#Selecting values from a DataFrame where a boolean condition is met:
df[df > 0]
# Out:
#                    A         B         C         D
# 2025-01-20       NaN       NaN       NaN  0.748727
# 2025-01-21  0.687145  0.184030  0.585852       NaN
# 2025-01-22  0.818708       NaN  0.538791  0.070809
# 2025-01-23  1.804694  0.135559       NaN       NaN
# 2025-01-24       NaN       NaN       NaN  0.517237
# 2025-01-25       NaN  0.775963  0.011384  1.002143

# %% [markdown]
# ### Setting

# %% [markdown]
# ##### Setting new column

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('2025-01-20', periods=6))
df['F'] = s1
df.head(3)
# Out:
#                    A         B         C         D  F
# 2025-01-20 -0.545678 -0.427257 -1.292691  0.748727  1
# 2025-01-21  0.687145  0.184030  0.585852 -0.533815  2
# 2025-01-22  0.818708 -0.090662  0.538791  0.070809  3

# %% [markdown]
# ##### Modifying column

# %%
df['D'] = np.array([5] * len(df))
df.head(3)
# Out:
#                    A         B         C  D  F
# 2025-01-20 -0.545678 -0.427257 -1.292691  5  1
# 2025-01-21  0.687145  0.184030  0.585852  5  2
# 2025-01-22  0.818708 -0.090662  0.538791  5  3

# %% [markdown]
# ##### Setting new element

# %%
df.at[dates[0], 'A'] = 0
df.iat[0, 1] = 0
df.iloc[0]
# Out:
# A    0.000000
# B    0.000000
# C   -1.292691
# D    5.000000
# F    1.000000
# Name: 2025-01-20 00:00:00, dtype: float64

# %% [markdown]
# ##### Setting new row

# %%
df.loc[pd.Timestamp('2025-01-29')] = np.append(np.random.randn(3), [5, 7])
df.tail(3)
# You can modify row like this also.
# Out:
#                    A         B         C    D    F
# 2025-01-24 -0.126337 -0.293950 -0.712291  5.0  5.0
# 2025-01-25 -0.697757  0.775963  0.011384  5.0  6.0
# 2025-01-29 -1.151677  1.011460 -0.379170  5.0  7.0

# %% [markdown]
# ##### Modifying the index of row

# %%
df.rename(index={pd.Timestamp('2025-01-29'): pd.Timestamp('2025-01-26')}, inplace=True)
df.tail(3)
# Out:
#                    A         B         C    D    F
# 2025-01-24 -0.126337 -0.293950 -0.712291  5.0  5.0
# 2025-01-25 -0.697757  0.775963  0.011384  5.0  6.0
# 2025-01-26 -1.151677  1.011460 -0.379170  5.0  7.0

# %% [markdown]
# ##### Removing column

# %%
df.drop('A', axis=1).head(3)

# df.drop('A', axis=1, inplace=True) will delete it permanently from memory.
# Out:
#                    B         C    D    F
# 2025-01-20  0.000000 -1.292691  5.0  1.0
# 2025-01-21  0.184030  0.585852  5.0  2.0
# 2025-01-22 -0.090662  0.538791  5.0  3.0

# %% [markdown]
# ##### Removing row

# %%
df.drop('2025-01-24')
# Out:
#                    A         B         C    D    F
# 2025-01-20  0.000000  0.000000 -1.292691  5.0  1.0
# 2025-01-21  0.687145  0.184030  0.585852  5.0  2.0
# 2025-01-22  0.818708 -0.090662  0.538791  5.0  3.0
# 2025-01-23  1.804694  0.135559 -0.007469  5.0  4.0
# 2025-01-25 -0.697757  0.775963  0.011384  5.0  6.0
# 2025-01-26 -1.151677  1.011460 -0.379170  5.0  7.0

# %% [markdown]
# ### Missing Data

# %% [markdown]
# #### Finding missing data

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df2 = pd.DataFrame(data)
df2
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df2.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df2.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %%
df2.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %% [markdown]
# #### Removing missing data

# %%
df2.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df2.dropna(thresh=3)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 4  5.0  5  NaN  5.0

# %% [markdown]
# #### Filling missing data

# %% [markdown]
# ##### By given values

# %%
df2.fillna(0)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  0.0
# 2  0.0  3  3.0  0.0
# 3  4.0  4  0.0  0.0
# 4  5.0  5  0.0  5.0

# %%
values = {'A':0,'B':100,"C":300,'D':400}
df2.fillna(value=values)
# Out:
#      A  B      C      D
# 0  1.0  1    1.0    1.0
# 1  2.0  2    2.0  400.0
# 2  0.0  3    3.0  400.0
# 3  4.0  4  300.0  400.0
# 4  5.0  5  300.0    5.0

# %% [markdown]
# ##### By combine_first()

# %%
df3 = pd.DataFrame(np.arange(-1,-31,-1).reshape(6,5), columns=list('ABCDE'))

# combine_first() will use second dataframe's values to fill nan values of first dataframe.
df2.combine_first(df3)

# Important about combine_first() :
# combine_first() aligns both DataFrames by their index and columns.
# It can also include labels and columns that exist only in one DataFrame.
# Out:
#       A   B     C     D   E
# 0   1.0   1   1.0   1.0  -5
# 1   2.0   2   2.0  -9.0 -10
# 2 -11.0   3   3.0 -14.0 -15
# 3   4.0   4 -18.0 -19.0 -20
# 4   5.0   5 -23.0   5.0 -25
# 5 -26.0 -27 -28.0 -29.0 -30

# %% [markdown]
# ##### By combine()

# %%
# combine() can combine values as defined.
temp_df1 = pd.DataFrame(np.array(np.random.randint(1,11,12)).reshape(4,3), columns=list('ABC'))
temp_df2 = pd.DataFrame(np.array(np.random.randint(1,11,12)).reshape(4,3), columns=list('ABC'))
print(temp_df1, '\n', temp_df2, '\n')

# Using in-built function
print(temp_df1.combine(temp_df2, max))

# Using custom(UDF / lambda function) function
def temp_func(x, y):
    if(x > y):
        return x + y
    else:
        return x - y
    
print(temp_df1.combine(temp_df2, temp_func))
# Out:
#     A  B  C
# 0   8  3  7
# 1   1  8  2
# 2  10  2  9
# 3   3  6  1
#      A  B  C
# 0   9  7  5
# 1   6  7  3
# 2  10  7  5
# 3   3  5  3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 7
#       3 temp_df2 = pd.DataFrame(np.array(np.random.randint(1,11,12)).reshape(4,3), columns=list('ABC'))
#       4 print(temp_df1, '\n', temp_df2, '\n')
#       5
#       6 # Using in-built function
# ----> 7 print(temp_df1.combine(temp_df2, max))
#       8
#       9 # Using custom(UDF / lambda function) function
#      10 def temp_func(x, y):
#
# File c:\full stack web developement\Repository\Python AI\myvenv\Lib\site-packages\pandas\core\frame.py:10349, in DataFrame.combine(self, other, func, fill_value, overwrite)
#   10345                 new_dtype = find_common_type([this_dtype, other_dtype])
#   10346                 series = series.astype(new_dtype)
# ...

# %% [markdown]
# ### Merge and Grouping

# %% [markdown]
# #### Merging

# %%
employees = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

salaries = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

# %%
employees
# Out:
#    employee_id   name department
# 0            1   John         HR
# 1            2   Anna         IT
# 2            3  Peter    Finance
# 3            4  Linda         IT
# 4            5    Bob         HR

# %%
salaries
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
pd.merge(employees, salaries)             # pd.merge(employees, salaries, on='employee_id', how='inner')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
pd.merge(employees, salaries, on='employee_id', how='outer')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %%
pd.merge(employees, salaries, on='employee_id', how='left')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN

# %%
pd.merge(employees, salaries, on='employee_id', how='right')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000
# 3            6    NaN        NaN   70000   8000
# 4            7    NaN        NaN   90000  12000

# %% [markdown]
# #### Concating

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2']
})

df2 = pd.DataFrame({
    'A': ['A3', 'A4', 'A5'],
    'B': ['B3', 'B4', 'B5'],
    'C': ['C3', 'C4', 'C5']
})

# %%
df1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
df2
# Out:
#     A   B   C
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1, df2])
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A3  B3  C3
# 1  A1  B1  C1  A4  B4  C4
# 2  A2  B2  C2  A5  B5  C5

# %% [markdown]
# #### Joining

# %%
df1 = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie']
}, index=[1, 2, 3])

df2 = pd.DataFrame({
    'score': [85, 90, 75]
}, index=[2, 3, 4])

print(df1, df2, sep='\n\n')
# Out:
#       name
# 1    Alice
# 2      Bob
# 3  Charlie
#
#    score
# 2     85
# 3     90
# 4     75

# %%
df1.join(df2)
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0

# %%
df1.join(df2, how='outer')
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0
# 4      NaN   75.0

# %% [markdown]
# #### Grouping

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df2 = pd.DataFrame(data)
df2
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
cat_group = df2.groupby('Category')
cat_group

# %%
cat_group = df2.groupby('Category')['Sales'].sum()
cat_group
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
store_group = df2.groupby('Store')['Sales'].sum()
store_group
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
combine_group = df2.groupby(['Category', 'Store'])['Sales'].sum()
combine_group
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %% [markdown]
# ### Stack and Pivot Tables

# %% [markdown]
# #### Stack & Unstack

# %%
arrays = [
   ["bar", "bar", "baz", "baz"],
   ["one", "two", "one", "two"],
]

index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
df = pd.DataFrame(np.random.randn(4, 2), index=index, columns=["A", "B"])
print(df, '\n')

stacked = df.stack()
print(stacked)
# Out:
#                      A         B
# first second
# bar   one    -0.041413  1.164425
#       two    -1.105338  2.233026
# baz   one    -1.152058  1.152668
#       two    -1.811472 -0.560159
#
# first  second
# bar    one     A   -0.041413
#                B    1.164425
#        two     A   -1.105338
#                B    2.233026
# baz    one     A   -1.152058
#                B    1.152668
#        two     A   -1.811472
#                B   -0.560159
# dtype: float64

# %%
unstacked = stacked.unstack()
print(unstacked, '\n')

unstacked = stacked.unstack(0)
print(unstacked, '\n')

unstacked = stacked.unstack(1)
print(unstacked)
# Out:
#                      A         B
# first second
# bar   one    -0.041413  1.164425
#       two    -1.105338  2.233026
# baz   one    -1.152058  1.152668
#       two    -1.811472 -0.560159
#
# first          bar       baz
# second
# one    A -0.041413 -1.152058
#        B  1.164425  1.152668
# two    A -1.105338 -1.811472
#        B  2.233026 -0.560159
#
# second        one       two
# first
# bar   A -0.041413 -1.105338
#       B  1.164425  2.233026
# baz   A -1.152058 -1.811472
#       B  1.152668 -0.560159

# %% [markdown]
# #### Pivot tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df2 = pd.DataFrame(data)

df2['Month'] = df2['Date'].dt.month_name()
df2['Quarter'] = 'Q' + df2['Date'].dt.quarter.astype(str)
df2
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    258     74   John  January      Q1
# 1  2023-01-02       B   West    444     72   Mary  January      Q1
# 2  2023-01-03       C  North    450     34    Bob  January      Q1
# 3  2023-01-04       D  South    805     86  Alice  January      Q1
# 4  2023-01-05       A   East    167     97   John  January      Q1
# 5  2023-01-06       B   West    406     60   Mary  January      Q1
# 6  2023-01-07       C  North    116     68    Bob  January      Q1
# 7  2023-01-08       D  South    921     82  Alice  January      Q1
# 8  2023-01-09       A   East    756     59   John  January      Q1
# 9  2023-01-10       B   West    896     12   Mary  January      Q1
# 10 2023-01-11       C  North    921     21    Bob  January      Q1
# 11 2023-01-12       D  South    595     16  Alice  January      Q1
# 12 2023-01-13       A   East    896     23   John  January      Q1
# ...

# %%
pivot_table_1 = pd.pivot_table(data=df2, values='Sales', index='Region', columns='Product')
pivot_table_1
# Out:
# Product      A      B      C      D
# Region
# East     439.6    NaN    NaN    NaN
# North      NaN    NaN  626.0    NaN
# South      NaN    NaN    NaN  620.0
# West       NaN  589.4    NaN    NaN

# %%
pivot_table_2 = pd.pivot_table(data=df2, values=['Sales', 'Units'], index='Region', columns='Product')
pivot_table_2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     439.6    NaN    NaN    NaN  58.0   NaN   NaN   NaN
# North      NaN    NaN  626.0    NaN   NaN   NaN  43.2   NaN
# South      NaN    NaN    NaN  620.0   NaN   NaN   NaN  70.4
# West       NaN  589.4    NaN    NaN   NaN  53.2   NaN   NaN

# %% [markdown]
# #### Crosstabs

# %%
crosstab_1 = pd.crosstab(df2['Region'], df2['Product'])
crosstab_1
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %% [markdown]
# ### Operations

# %% [markdown]
# #### Dataframes basic operations

# %% [markdown]
# ##### Aggregation functions

# %%
df1 = pd.DataFrame({
    'Id': [1, 2, 3, 4, 5],
    'Price': [600, 720, 590, 650, 700],
    'Sales': [1000, 1000, 1200, 900, 1000]
})
df1
# Out:
#    Id  Price  Sales
# 0   1    600   1000
# 1   2    720   1000
# 2   3    590   1200
# 3   4    650    900
# 4   5    700   1000

# %%
print('Mean : ', df1['Sales'].mean())
print('Sum : ', df1['Sales'].sum())
print('Min : ', df1['Sales'].min())
print('Max : ', df1['Sales'].max())
print('Count : ', df1['Sales'].count())
print('Std : ', df1['Sales'].std())
print('Median : ', df1['Sales'].median())
# Out:
# Mean :  1020.0
# Sum :  5100
# Min :  900
# Max :  1200
# Count :  5
# Std :  109.54451150103323
# Median :  1000.0

# %%
df1['Sales'].agg(['mean', 'min', 'max', 'sum', 'count', 'std', 'median'])
# Out:
# mean      1020.000000
# min        900.000000
# max       1200.000000
# sum       5100.000000
# count        5.000000
# std        109.544512
# median    1000.000000
# Name: Sales, dtype: float64

# %% [markdown]
# ##### mode function

# %%
# mode function returns the most frequently occured values in a series or a dataframe.
s = pd.Series(np.array([1, 2, 3, 2, 2, 1]), index=list('abcdef'))
s.mode()

s2 = pd.Series(np.array([1, 3, 3, 1, 2, 4]), index=list('abcdef'))
s2.mode()
# Out:
# 0    1
# 1    3
# dtype: int64

# %% [markdown]
# ##### Vectorized Operations

# %%
# Every value will be multiplied by 10
df1 * 10
# Out:
#    Id  Price  Sales
# 0  10   6000  10000
# 1  20   7200  10000
# 2  30   5900  12000
# 3  40   6500   9000
# 4  50   7000  10000

# %% [markdown]
# #### Applying functions

# %%
def square(x):
    return x**2

# %%
df1['Id'].apply(square)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# Name: Id, dtype: int64

# %%
df1['raw Id'] = df1['Id'].apply(lambda x: x**3)
df1
# Out:
#    Id  Price  Sales  raw Id
# 0   1    600   1000       1
# 1   2    720   1000       8
# 2   3    590   1200      27
# 3   4    650    900      64
# 4   5    700   1000     125
