# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Basics

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# #### basic plotting

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

print(x, y, sep='\n')
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %%
plt.plot(x,y)
plt.title("Graph of x and y")
plt.xlabel("x values")
plt.ylabel("y values")
# Out:
# Text(0, 0.5, 'y values')

# %% [markdown]
# #### Subplots

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)

# %% [markdown]
# #### Object Oriented Way

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches and dpi is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(7,7), dpi=100)

axis1 = fig.add_axes([.1, .1, 1, 1])
axis1.plot(x, y)

axis2 = fig.add_axes([.3, .6, .4, .4])
axis2.plot(x, y)

# %% [markdown]
# #### Types of plots

# %%
plt.scatter(x, y)

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d2c0e5fed0>,
#   <matplotlib.lines.Line2D at 0x1d2c0b70050>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d2c0b70190>,
#   <matplotlib.lines.Line2D at 0x1d2c0b702d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d2c0e5fd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d2c0b70410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d2c0b70550>],
#  'means': []}

# %% [markdown]
# #### Saving plots

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("files & images/basicplot.png")

# %% [markdown]
# #### Working with images

# %% [markdown]
# ##### Showing image

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('files & images/Hanuman Wallpaper.jpg')
plt.imshow(img)

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(735.5), np.float64(411.5), np.float64(-0.5))

# %% [markdown]
# ##### Cropping image

# %%
cropped_img = img[25:475, 100:660]
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(559.5), np.float64(386.5), np.float64(-0.5))

# %% [markdown]
# #### Optional Designing

# %%
xaxis = np.linspace(0,5,11)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green")

# %% [markdown]
# ### Seaborn

# %% [markdown]
# #### histplot

# %%
df = sns.load_dataset('tips')
df
# This dataset is installed by seaborn itself.
# total_bill, tip, are quantitive data while sex, smoker, day, time, size are qualitive data.
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(df['total_bill'], kde=True, bins=15)
# kde draws the line of probability density.
# bins defines how many boxes would be created.
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# #### joinplot

# %%
sns.jointplot(x='total_bill', y='tip', data=df)

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='reg')
# Default value of kind is scatter.

# %% [markdown]
# #### pairplot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='sex')

# %% [markdown]
# #### rugplot

# %%
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>
